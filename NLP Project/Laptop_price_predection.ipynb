# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import string
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud

# %%
data=pd.read_csv(r"laptop_price.csv")
data.head(5)
# Out:
#    Country Laptop_Brand  RAM_GB  Storage_GB  CPU_Performance  Price_USD  \
# 0   Brazil         Acer       8        2048             3138    2695.70
# 1  Germany       Lenovo      64         256              472    1848.26
# 2   Canada           HP      16         512             1336    2311.62
# 3       UK       Lenovo      64        2048             3348    5126.20
# 4   Brazil         Asus      16        2048             2592    3167.03
#
#         Usage_Type
# 0     Professional
# 1            Basic
# 2          Student
# 3  High-End Gaming
# 4     Professional

# %%
data.isnull().sum()
# Out:
# Country            0
# Laptop_Brand       0
# RAM_GB             0
# Storage_GB         0
# CPU_Performance    0
# Price_USD          0
# Usage_Type         0
# dtype: int64

# %%
data['Country'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           Brazil
# 1          Germany
# 2           Canada
# 3               UK
# 4           Brazil
#             ...
# 1048570        USA
# 1048571    Germany
# 1048572        UAE
# 1048573    Germany
# 1048574    Germany
# Name: Country, Length: 1048575, dtype: object>
